# %% [markdown]
# # Lecture 7 : POS Tagging | Part of Speech Tagging in NLP | Hidden Markov Models in NLP | Viterbi Algorithm in NLP

# %% [markdown]
# https://www.youtube.com/watch?v=269IGagoJfs&list=PLKnIA16_RmvZo7fp5kkIth6nRTeQQsjfX&index=7

# %% [markdown]
# Part-of-speech (POS) tagging, also known as grammatical tagging or word category disambiguation, is a fundamental task in natural language processing (NLP). __It involves assigning a specific grammatical label or tag to each word in a given sentence__, indicating its syntactic role and grammatical category.
#
# The POS tags represent different parts of speech such as nouns, verbs, adjectives, adverbs, pronouns, prepositions, conjunctions, and more. The tags provide information about the word's function and its relationship with other words in the sentence.

# %% [markdown]
# ##### POS tagging is crucial in various NLP tasks, including:
#
# 1. __Parsing :__ POS tags serve as input to syntactic parsers, helping determine the grammatical structure and relationships between words in a sentence.
#
#
# 2. __Named Entity Recognition (NER) :__ POS tags can aid in identifying named entities by distinguishing between proper nouns, common nouns, and other word categories.
#
#
# 3. __Machine Translation :__ POS tags can assist in improving translation accuracy by capturing the correct syntactic structure of the source sentence.
#
#
# 4. __Sentiment Analysis :__ POS tags can be used to extract features for sentiment analysis, as certain parts of speech may carry sentiment information (e.g., adjectives and adverbs).
#
# POS tagging can be approached using different techniques, including rule-based methods, statistical models, and machine learning algorithms. Rule-based approaches use handcrafted rules based on linguistic knowledge, while statistical models and machine learning algorithms rely on annotated corpora to learn patterns and associations between words and their corresponding tags.
#
#
#
# Popular algorithms used for POS tagging include Hidden Markov Models (HMMs), Maximum Entropy Markov Models (MEMMs), Conditional Random Fields (CRFs), and deep learning models like Recurrent Neural Networks (RNNs) or Transformers.

# %%
import spacy

# %% [markdown]
# ##### import english language dictionary :

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u'I will google about facebook')

# %%
doc.text
# Out:
# 'I will google about facebook'

# %%
for i in range(len(doc)):
    print(doc[i],"---------->",doc[i].tag_,"------->",doc[i].pos_,"------->",spacy.explain(doc[i].tag_),"\n")
# Out:
# I ----------> PRP -------> PRON -------> pronoun, personal
#
# will ----------> MD -------> AUX -------> verb, modal auxiliary
#
# google ----------> VB -------> VERB -------> verb, base form
#
# about ----------> IN -------> ADP -------> conjunction, subordinating or preposition
#
# facebook ----------> NN -------> NOUN -------> noun, singular or mass

# %%
doc2 = nlp(u"I left the room")

for i in range(len(doc2)):
    print(doc2[i],"---------->",doc2[i].tag_,"------->",doc2[i].pos_,"------->",spacy.explain(doc2[i].tag_),"\n")
# Out:
# I ----------> PRP -------> PRON -------> pronoun, personal
#
# left ----------> VBD -------> VERB -------> verb, past tense
#
# the ----------> DT -------> DET -------> determiner
#
# room ----------> NN -------> NOUN -------> noun, singular or mass

# %%
doc3 = nlp(u"to the left of the room")

for i in range(len(doc3)):
    print(doc3[i],"---------->",doc3[i].tag_,"------->",doc3[i].pos_,"------->",spacy.explain(doc3[i].tag_),"\n")
# Out:
# to ----------> IN -------> ADP -------> conjunction, subordinating or preposition
#
# the ----------> DT -------> DET -------> determiner
#
# left ----------> NN -------> NOUN -------> noun, singular or mass
#
# of ----------> IN -------> ADP -------> conjunction, subordinating or preposition
#
# the ----------> DT -------> DET -------> determiner
#
# room ----------> NN -------> NOUN -------> noun, singular or mass

# %%
doc4 = nlp(u"I read books on history")
for word in doc4:
    print(word.text,"------>", word.tag_,"------>",word.pos_,"------>",spacy.explain(word.tag_),"\n")
# Out:
# I ------> PRP ------> PRON ------> pronoun, personal
#
# read ------> VBP ------> VERB ------> verb, non-3rd person singular present
#
# books ------> NNS ------> NOUN ------> noun, plural
#
# on ------> IN ------> ADP ------> conjunction, subordinating or preposition
#
# history ------> NN ------> NOUN ------> noun, singular or mass

# %%
doc5 = nlp(u"I have read a book on history")
for word in doc5:
    print(word.text,"------>", word.tag_,"------>",word.pos_,"------>",spacy.explain(word.tag_),"\n")
# Out:
# I ------> PRP ------> PRON ------> pronoun, personal
#
# have ------> VBP ------> AUX ------> verb, non-3rd person singular present
#
# read ------> VBN ------> VERB ------> verb, past participle
#
# a ------> DT ------> DET ------> determiner
#
# book ------> NN ------> NOUN ------> noun, singular or mass
#
# on ------> IN ------> ADP ------> conjunction, subordinating or preposition
#
# history ------> NN ------> NOUN ------> noun, singular or mass

# %%
doc6 = nlp(u"The quick brown fox jumped over the lazy dog")

# %%
from spacy import displacy

# %%
displacy.render(doc6,style = 'dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cbca9fcd148f4727a210ebb93aaa87a4-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">jumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-7" stroke-width="2px" d="M945,264.5 C945,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbca9fcd148f4727a210ebb93aaa87a4-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
options={
    'distance':80,
    'compact':True,
    'color':'#fff',
    'bg':'#00a65a'
}

# %%
displacy.render(doc6,style='dep',jupyter=True,options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="439b768e75e84fb79ccc84b312623c7c-0" class="displacy" width="770" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #fff; background: #00a65a; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">jumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-439b768e75e84fb79ccc84b312623c7c-0-0" stroke-width="2px" d="M62,122.0 62,82.0 290.0,82.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-439b768e75e84fb79ccc84b312623c7c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,124.0 L58,116.0 66,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-439b768e75e84fb79ccc84b312623c7c-0-1" stroke-width="2px" d="M142,122.0 142,95.33333333333333 287.0,95.33333333333333 287.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-439b768e75e84fb79ccc84b312623c7c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M142,124.0 L138,116.0 146,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-439b768e75e84fb79ccc84b312623c7c-0-2" stroke-width="2px" d="M222,122.0 222,108.66666666666667 284.0,108.66666666666667 284.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-439b768e75e84fb79ccc84b312623c7c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M222,124.0 L218,116.0 226,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-439b768e75e84fb79ccc84b312623c7c-0-3" stroke-width="2px" d="M302,122.0 302,108.66666666666667 364.0,108.66666666666667 364.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-439b768e75e84fb79ccc84b312623c7c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M302,124.0 L298,116.0 306,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-439b768e75e84fb79ccc84b312623c7c-0-4" stroke-width="2px" d="M382,122.0 382,108.66666666666667 444.0,108.66666666666667 444.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-439b768e75e84fb79ccc84b312623c7c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M444.0,124.0 L448.0,116.0 440.0,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-439b768e75e84fb79ccc84b312623c7c-0-5" stroke-width="2px" d="M542,122.0 542,95.33333333333333 687.0,95.33333333333333 687.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-439b768e75e84fb79ccc84b312623c7c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M542,124.0 L538,116.0 546,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-439b768e75e84fb79ccc84b312623c7c-0-6" stroke-width="2px" d="M622,122.0 622,108.66666666666667 684.0,108.66666666666667 684.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-439b768e75e84fb79ccc84b312623c7c-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M622,124.0 L618,116.0 626,116.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-439b768e75e84fb79ccc84b312623c7c-0-7" stroke-width="2px" d="M462,122.0 462,82.0 690.0,82.0 690.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-439b768e75e84fb79ccc84b312623c7c-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M690.0,124.0 L694.0,116.0 686.0,116.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Hidden Markov Model

# %% [markdown]
# https://www.youtube.com/watch?v=kqSzLo9fenk

# %% [markdown]
# ![Screenshot%202023-06-17%20181142.png](attachment:Screenshot%202023-06-17%20181142.png)

# %% [markdown]
# ### 1. How do we find these probabilities

# %% [markdown]
# ![Screenshot%202023-06-17%20181738-2.png](attachment:Screenshot%202023-06-17%20181738-2.png)

# %% [markdown]
# ### 2. What is the probability that a Random day is Sunny or Rainy?

# %% [markdown]
# ![Screenshot%202023-06-17%20182043.png](attachment:Screenshot%202023-06-17%20182043.png)

# %% [markdown]
# ### 3. If Bob is Happy today, what's the probability that it's Sunny or Rainy?

# %% [markdown]
# ![Screenshot%202023-06-17%20182754.png](attachment:Screenshot%202023-06-17%20182754.png)

# %% [markdown]
# #### Prior probabilities :

# %% [markdown]
# ![Screenshot%202023-06-17%20182404.png](attachment:Screenshot%202023-06-17%20182404.png)

# %% [markdown]
# #### Posterior Probabilities :

# %% [markdown]
# ![Screenshot%202023-06-17%20182653.png](attachment:Screenshot%202023-06-17%20182653.png)

# %% [markdown]
# ### 4. If for three days bob is Happy, grumpy, Happy what was the weather?

# %% [markdown]
# ![Screenshot%202023-06-17%20184134.png](attachment:Screenshot%202023-06-17%20184134.png)

# %% [markdown]
# #### All probabilities for 2 days:

# %% [markdown]
# ![Screenshot%202023-06-17%20183604.png](attachment:Screenshot%202023-06-17%20183604.png)

# %% [markdown]
# #### All probabilities for 3 days :

# %% [markdown]
# ![Screenshot%202023-06-17%20184256.png](attachment:Screenshot%202023-06-17%20184256.png)

# %% [markdown]
# ![Screenshot%202023-06-17%20184714.png](attachment:Screenshot%202023-06-17%20184714.png)

# %% [markdown]
# ## Viterbi Algorithm

# %% [markdown]
# The Viterbi algorithm is a method used to find the most probable sequence of hidden states in a sequence of observations.
#
#
# It works by considering the probabilities of transitioning between states and emitting observations. By efficiently calculating these probabilities, the algorithm helps determine the most likely sequence of hidden states in a model, such as predicting the part-of-speech tags for a given sentenc

# %% [markdown]
# #### best path leading to happy (maximum probability) :

# %% [markdown]
# ![Screenshot%202023-06-17%20185443.png](attachment:Screenshot%202023-06-17%20185443.png)

# %% [markdown]
# ![Screenshot%202023-06-18%20051014.png](attachment:Screenshot%202023-06-18%20051014.png)

# %% [markdown]
# ![Screenshot%202023-06-18%20050750.png](attachment:Screenshot%202023-06-18%20050750.png)

# %% [markdown]
# #### best path
#
# ![Screenshot%202023-06-18%20050805.png](attachment:Screenshot%202023-06-18%20050805.png)

# %% [markdown]
# ![Screenshot%202023-06-18%20051138.png](attachment:Screenshot%202023-06-18%20051138.png)

# %% [markdown]
# ## How POS Tagging works

# %% [markdown]
# - __Emission Probability :__ Emission probability refers to the probability of observing a particular word given a specific POS tag. It captures the likelihood of a word being associated with a particular part-of-speech. For example, the emission probability of the word "cat" being a noun (NN) would represent how likely it is for the word "cat" to be tagged as a noun.
#
#
# - __Transition Probability :__ Transition probability refers to the probability of transitioning from one POS tag to another. It represents the likelihood of a particular POS tag following another POS tag in a sequence. For example, the transition probability from a verb (VB) to a noun (NN) would indicate how likely it is for a verb to be followed by a noun in a sentence.

# %% [markdown]
# ![Screenshot%202023-06-18%20052258.png](attachment:Screenshot%202023-06-18%20052258.png)

# %% [markdown]
# ![Screenshot%202023-06-18%20053046.png](attachment:Screenshot%202023-06-18%20053046.png)

# %% [markdown]
# - upar we are using emisson values and neeche we are using transition values
#
#
# - The path with highest product value will be the one to be used.

# %% [markdown]
# ## Viterbi Algo

# %% [markdown]
# ##### all emmison probabilities are written here :

# %% [markdown]
# ![Screenshot%202023-06-18%20053818.png](attachment:Screenshot%202023-06-18%20053818.png)

# %% [markdown]
# ##### another example :

# %% [markdown]
# ![Screenshot%202023-06-19%20033057.png](attachment:Screenshot%202023-06-19%20033057.png)

# %% [markdown]
# # Remaining Topics :
#
# - Topic Modelling
#
#
# - name entity regocgnition
